# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
# loading csv file
car_df=pd.read_csv("Resources/cars_summary.csv")
# car_df.head(5)
print(car_df.count)
# Out:
# <bound method DataFrame.count of           car_id                          name  year  selling_price    fuel  \
# 0         CarID1        Maruti Swift Dzire VDI  2014         450000  Diesel
# 1        Car ID2  Skoda Rapid 1.5 TDI Ambition  2014         370000  Diesel
# 2        Car ID3      Honda City 2017-2020 EXi  2006         158000  Petrol
# 3        Car ID4     Hyundai i20 Sportz Diesel  2010         225000  Diesel
# 4        Car ID5        Maruti Swift VXI BSIII  2007         130000  Petrol
# ...          ...                           ...   ...            ...     ...
# 8123  Car ID8124             Hyundai i20 Magna  2013         320000  Petrol
# 8124  Car ID8125         Hyundai Verna CRDi SX  2007         135000  Diesel
# 8125  Car ID8126        Maruti Swift Dzire ZDi  2009         382000  Diesel
# 8126  Car ID8127               Tata Indigo CR4  2013         290000  Diesel
# 8127  Car ID8128               Tata Indigo CR4  2013         290000  Diesel
#
# ...

# %%
# dropna for each row
car_dropna_df= car_df.dropna(how="any")
# car_dropna_df.head(20)
print(car_dropna_df.count)
# Out:
# <bound method DataFrame.count of           car_id                          name  year  selling_price    fuel  \
# 0         CarID1        Maruti Swift Dzire VDI  2014         450000  Diesel
# 1        Car ID2  Skoda Rapid 1.5 TDI Ambition  2014         370000  Diesel
# 2        Car ID3      Honda City 2017-2020 EXi  2006         158000  Petrol
# 3        Car ID4     Hyundai i20 Sportz Diesel  2010         225000  Diesel
# 4        Car ID5        Maruti Swift VXI BSIII  2007         130000  Petrol
# ...          ...                           ...   ...            ...     ...
# 8123  Car ID8124             Hyundai i20 Magna  2013         320000  Petrol
# 8124  Car ID8125         Hyundai Verna CRDi SX  2007         135000  Diesel
# 8125  Car ID8126        Maruti Swift Dzire ZDi  2009         382000  Diesel
# 8126  Car ID8127               Tata Indigo CR4  2013         290000  Diesel
# 8127  Car ID8128               Tata Indigo CR4  2013         290000  Diesel
#
# ...

# %%
car_dropna_df.head(20)
# Out:
#       car_id                                  name  year  selling_price  \
# 0     CarID1                Maruti Swift Dzire VDI  2014         450000
# 1    Car ID2          Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2    Car ID3              Honda City 2017-2020 EXi  2006         158000
# 3    Car ID4             Hyundai i20 Sportz Diesel  2010         225000
# 4    Car ID5                Maruti Swift VXI BSIII  2007         130000
# 5    Car ID6         Hyundai Xcent 1.2 VTVT E Plus  2017         440000
# 6    Car ID7          Maruti Wagon R LXI DUO BSIII  2007          96000
# 7    Car ID8                    Maruti 800 DX BSII  2001          45000
# 8    Car ID9                      Toyota Etios VXD  2011         350000
# 9   Car ID10  Ford Figo Diesel Celebration Edition  2013         200000
# 10  Car ID11       Renault Duster 110PS Diesel RxL  2014         500000
# 11  Car ID12                         Maruti Zen LX  2005          92000
# ...

# %%
# sperate name for car brand and model
car_dropna_df[['manufactory','type']] =  car_dropna_df["name"].str.split(" ", n=1, expand=True)
car_dropna_df.head()
# Out:
# C:\Users\weiti\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#     car_id                          name  year  selling_price    fuel  \
# 0   CarID1        Maruti Swift Dzire VDI  2014         450000  Diesel
# 1  Car ID2  Skoda Rapid 1.5 TDI Ambition  2014         370000  Diesel
# 2  Car ID3      Honda City 2017-2020 EXi  2006         158000  Petrol
# 3  Car ID4     Hyundai i20 Sportz Diesel  2010         225000  Diesel
# 4  Car ID5        Maruti Swift VXI BSIII  2007         130000  Petrol
#
#   seller_type  km_driven         owner     mileage manufactory  \
# 0  Individual     145500   First Owner   23.4 kmpl      Maruti
# ...

# %%
# Select column
car_clean_df=car_dropna_df[['manufactory',"year","selling_price","fuel","seller_type","mileage"]]
car_clean_df
# Out:
#      manufactory  year  selling_price    fuel seller_type     mileage
# 0         Maruti  2014         450000  Diesel  Individual   23.4 kmpl
# 1          Skoda  2014         370000  Diesel  Individual  21.14 kmpl
# 2          Honda  2006         158000  Petrol  Individual   17.7 kmpl
# 3        Hyundai  2010         225000  Diesel  Individual   23.0 kmpl
# 4         Maruti  2007         130000  Petrol  Individual   16.1 kmpl
# ...          ...   ...            ...     ...         ...         ...
# 8123     Hyundai  2013         320000  Petrol  Individual   18.5 kmpl
# 8124     Hyundai  2007         135000  Diesel  Individual   16.8 kmpl
# 8125      Maruti  2009         382000  Diesel  Individual   19.3 kmpl
# 8126        Tata  2013         290000  Diesel  Individual  23.57 kmpl
# 8127        Tata  2013         290000  Diesel  Individual  23.57 kmpl
#
# [7907 rows x 6 columns]

# %%
# Clean fuel types
car_clean_df['fuel'] = car_clean_df['fuel'].replace(['CNG', 'LPG'], 'Other')
# Out:
# <ipython-input-7-e4d823f7566f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_clean_df['fuel'] = car_clean_df['fuel'].replace(['CNG', 'LPG'], 'Other')

# %%
car_clean_df.dtypes
# Out:
# manufactory      object
# year              int64
# selling_price     int64
# fuel             object
# seller_type      object
# mileage          object
# dtype: object

# %%
car_over17=car_clean_df[car_clean_df["year"]>2017]

print(car_over17.count)
# Out:
# <bound method DataFrame.count of      manufactory  year  selling_price    fuel seller_type      mileage
# 24          Tata  2018         500000  Petrol  Individual    20.3 kmpl
# 29        Maruti  2018         254999  Petrol  Individual    16.8 kmpl
# 33       Hyundai  2018         730000  Petrol  Individual    18.6 kmpl
# 35        Maruti  2019         330000   Other  Individual  33.44 km/kg
# 36        Maruti  2019         366000  Petrol  Individual   23.95 kmpl
# ...          ...   ...            ...     ...         ...          ...
# 8097        Ford  2018         880000  Diesel  Individual    23.0 kmpl
# 8100        Tata  2018         800000  Diesel  Individual    21.5 kmpl
# 8108         Kia  2019        1575000  Diesel  Individual    17.8 kmpl
# 8109        Ford  2018         750000  Diesel  Individual    24.4 kmpl
# 8112        Ford  2018         746000  Diesel  Individual    24.4 kmpl
#
# [1463 rows x 6 columns]>

# %%
# save clean data 
car_over17.to_csv("Resources/car_clean.csv")
